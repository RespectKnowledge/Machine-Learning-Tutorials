# %%
import pandas as pd

# %%
# check pandas version
print(pd.__version__)
# Out:
# 0.24.2

# %%
# create series, manipulate, auerry
arr=[0,1,2,3,4]
s1=pd.Series(arr)
s1
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# dtype: int64

# %%
order=[1,2,3,4,5]
s2=pd.Series(arr, index=order)
s2
# Out:
# 1    0
# 2    1
# 3    2
# 4    3
# 5    4
# dtype: int64

# %%
import numpy as np
n=np.random.randn(5)
s3=pd.Series(n)
s3
# Out:
# 0   -0.645793
# 1   -1.207284
# 2   -1.187247
# 3   -0.382100
# 4    2.978938
# dtype: float64

# %%
import numpy as np
n=np.random.randn(5)
index=['a','b','c','d','e']
s2=pd.Series(n, index=index)
s2
# Out:
# a   -0.855528
# b    0.793482
# c    0.555224
# d    0.960441
# e    0.004135
# dtype: float64

# %%
print(s1)
s1.index=['A','B','C','D','E']
s1
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# dtype: int64
# A    0
# B    1
# C    2
# D    3
# E    4
# dtype: int64

# %%
d={'a':1,'b':2,'c':3,'d':4,'e':5}
s3=pd.Series(d)
s3
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
s1[1:3]
s1[-2:]
s1[:-1]
# Out:
# A    0
# B    1
# C    2
# D    3
# dtype: int64

# %%
s2[1:3]
# Out:
# b    0.793482
# c    0.555224
# dtype: float64

# %%
# append series
s4=s1.append(s3)
s4
# Out:
# A    0
# B    1
# C    2
# D    3
# E    4
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
s4.drop('e')
s4
# Out:
# A    0
# B    1
# C    2
# D    3
# E    4
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
s4
# Out:
# A    0
# B    1
# C    2
# D    3
# E    4
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
# series operations
arr1=[0,3,4,5,6,7]
arr2=[5,9,0,11]
s5=pd.Series(arr1)
s6=pd.Series(arr2)
s5.add(s6)
# Out:
# 0     5.0
# 1    12.0
# 2     4.0
# 3    16.0
# 4     NaN
# 5     NaN
# dtype: float64

# %%
s5.sub(s6)
# Out:
# 0   -5.0
# 1   -6.0
# 2    4.0
# 3   -6.0
# 4    NaN
# 5    NaN
# dtype: float64

# %%
s5.mul(s6)
# Out:
# 0     0.0
# 1    27.0
# 2     0.0
# 3    55.0
# 4     NaN
# 5     NaN
# dtype: float64

# %%
s5.div(s6)
# Out:
# 0    0.000000
# 1    0.333333
# 2         inf
# 3    0.454545
# 4         NaN
# 5         NaN
# dtype: float64

# %%
print('median',s6.median())
print('max', s6.max())
print('min', s6.min())
# Out:
# median 7.0
# max 11
# min 0

# %% [markdown]
# Create Dataframe

# %%
dates=pd.date_range('today',periods=6)
dates
# Out:
# DatetimeIndex(['2019-04-28 07:35:28.444800', '2019-04-29 07:35:28.444800',
#                '2019-04-30 07:35:28.444800', '2019-05-01 07:35:28.444800',
#                '2019-05-02 07:35:28.444800', '2019-05-03 07:35:28.444800'],
#               dtype='datetime64[ns]', freq='D')

# %% [markdown]
# # Create DataFrame

# %%
dates=pd.date_range('today',periods=6)
dates
num_arr=np.random.randn(6,4)
num_arr
columns=['A','B','C','D']
columns

df1=pd.DataFrame(num_arr,index=dates,columns=columns)
df1
# Out:
#                                    A         B         C         D
# 2019-04-28 07:38:16.276562 -0.012319 -0.432980 -0.902458  2.100929
# 2019-04-29 07:38:16.276562  0.904501  1.865786  0.689380 -0.695606
# 2019-04-30 07:38:16.276562  1.867662 -0.924667  0.330726 -0.858128
# 2019-05-01 07:38:16.276562  0.141418 -1.231928 -1.104584  1.931464
# 2019-05-02 07:38:16.276562  1.542539  0.429264  1.365090 -1.071329
# 2019-05-03 07:38:16.276562 -0.285704 -0.776608  1.168256  0.167486

# %%
# create dataframe with dictionray
data={'student':['abdul','haroon','ali','arlan','alishah','saad','rubeena','sadia','rana','rabia'],
     'grads':[70,89,90,33,78,90,89,88,87,100],
     'studyhour':[10,2.5,20,15,14,10,8,9,2,11],
     'results':['pass','pass','pass','fail','pass','pass','pass','pass','pass','pass']}
data
labels=['a','b','c','d','e','f','g','h','i','j']
df2=pd.DataFrame(data,index=labels)
df2
# Out:
#    student  grads  studyhour results
# a    abdul     70       10.0    pass
# b   haroon     89        2.5    pass
# c      ali     90       20.0    pass
# d    arlan     33       15.0    fail
# e  alishah     78       14.0    pass
# f     saad     90       10.0    pass
# g  rubeena     89        8.0    pass
# h    sadia     88        9.0    pass
# i     rana     87        2.0    pass
# j    rabia    100       11.0    pass

# %%
df2.dtypes
# Out:
# student       object
# grads          int64
# studyhour    float64
# results       object
# dtype: object

# %%
df2.head()
# Out:
#    student  grads  studyhour results
# a    abdul     70       10.0    pass
# b   haroon     89        2.5    pass
# c      ali     90       20.0    pass
# d    arlan     33       15.0    fail
# e  alishah     78       14.0    pass

# %%
df2.tail()
# Out:
#    student  grads  studyhour results
# f     saad     90       10.0    pass
# g  rubeena     89        8.0    pass
# h    sadia     88        9.0    pass
# i     rana     87        2.0    pass
# j    rabia    100       11.0    pass

# %%
df2.index
df2.columns
# Out:
# Index(['student', 'grads', 'studyhour', 'results'], dtype='object')

# %%
df2.values
# Out:
# array([['abdul', 70, 10.0, 'pass'],
#        ['haroon', 89, 2.5, 'pass'],
#        ['ali', 90, 20.0, 'pass'],
#        ['arlan', 33, 15.0, 'fail'],
#        ['alishah', 78, 14.0, 'pass'],
#        ['saad', 90, 10.0, 'pass'],
#        ['rubeena', 89, 8.0, 'pass'],
#        ['sadia', 88, 9.0, 'pass'],
#        ['rana', 87, 2.0, 'pass'],
#        ['rabia', 100, 11.0, 'pass']], dtype=object)

# %%
df2.describe()
# Out:
#             grads  studyhour
# count   10.000000  10.000000
# mean    81.400000  10.150000
# std     18.762847   5.446967
# min     33.000000   2.000000
# 25%     80.250000   8.250000
# 50%     88.500000  10.000000
# 75%     89.750000  13.250000
# max    100.000000  20.000000

# %%
df2.T
# Out:
#                a       b     c      d        e     f        g      h     i  \
# student    abdul  haroon   ali  arlan  alishah  saad  rubeena  sadia  rana
# grads         70      89    90     33       78    90       89     88    87
# studyhour     10     2.5    20     15       14    10        8      9     2
# results     pass    pass  pass   fail     pass  pass     pass   pass  pass
#
#                j
# student    rabia
# grads        100
# studyhour     11
# results     pass

# %%
df2.sort_values(by='grads')
# Out:
#    student  grads  studyhour results
# d    arlan     33       15.0    fail
# a    abdul     70       10.0    pass
# e  alishah     78       14.0    pass
# i     rana     87        2.0    pass
# h    sadia     88        9.0    pass
# b   haroon     89        2.5    pass
# g  rubeena     89        8.0    pass
# c      ali     90       20.0    pass
# f     saad     90       10.0    pass
# j    rabia    100       11.0    pass

# %%
df2[1:3]
# Out:
#   student  grads  studyhour results
# b  haroon     89        2.5    pass
# c     ali     90       20.0    pass

# %%
df2.sort_values(by='grads')[1:4]
# Out:
#    student  grads  studyhour results
# a    abdul     70       10.0    pass
# e  alishah     78       14.0    pass
# i     rana     87        2.0    pass

# %%
df2.sort_values(by='grads')[1:8]
# Out:
#    student  grads  studyhour results
# a    abdul     70       10.0    pass
# e  alishah     78       14.0    pass
# i     rana     87        2.0    pass
# h    sadia     88        9.0    pass
# b   haroon     89        2.5    pass
# g  rubeena     89        8.0    pass
# c      ali     90       20.0    pass

# %%
df2[['student','grads']]
# Out:
#    student  grads
# a    abdul     70
# b   haroon     89
# c      ali     90
# d    arlan     33
# e  alishah     78
# f     saad     90
# g  rubeena     89
# h    sadia     88
# i     rana     87
# j    rabia    100

# %%
df3=df2.copy()
df3
# Out:
#    student  grads  studyhour results
# a    abdul     70       10.0    pass
# b   haroon     89        2.5    pass
# c      ali     90       20.0    pass
# d    arlan     33       15.0    fail
# e  alishah     78       14.0    pass
# f     saad     90       10.0    pass
# g  rubeena     89        8.0    pass
# h    sadia     88        9.0    pass
# i     rana     87        2.0    pass
# j    rabia    100       11.0    pass

# %%
df2.iloc[1:3]
# Out:
#   student  grads  studyhour results
# b  haroon     89        2.5    pass
# c     ali     90       20.0    pass

# %%
df2.iloc[1:7]
# Out:
#    student  grads  studyhour results
# b   haroon     89        2.5    pass
# c      ali     90       20.0    pass
# d    arlan     33       15.0    fail
# e  alishah     78       14.0    pass
# f     saad     90       10.0    pass
# g  rubeena     89        8.0    pass

# %%
df3.isnull()
# Out:
#    student  grads  studyhour  results
# a    False  False      False    False
# b    False  False      False    False
# c    False  False      False    False
# d    False  False      False    False
# e    False  False      False    False
# f    False  False      False    False
# g    False  False      False    False
# h    False  False      False    False
# i    False  False      False    False
# j    False  False      False    False

# %%
df3.loc[['h','j']]
# Out:
#   student  grads  studyhour results
# h   sadia     88        9.0    pass
# j   rabia    100       11.0    pass

# %%
df3.mean()
# Out:
# grads        81.40
# studyhour    10.15
# dtype: float64

# %%
df3['grads'].sum()
df3['grads'].mean()
# Out:
# 81.4

# %%
df3.sum()
# Out:
# student      abdulharoonaliarlanalishahsaadrubeenasadiarana...
# grads                                                      814
# studyhour                                                101.5
# results               passpasspassfailpasspasspasspasspasspass
# dtype: object

# %%
string=pd.Series(['A','DE','BN','C',np.nan,'con','b','c'])
string
# Out:
# 0      A
# 1     DE
# 2     BN
# 3      C
# 4    NaN
# 5    con
# 6      b
# 7      c
# dtype: object

# %%
string.str.lower()
# Out:
# 0      a
# 1     de
# 2     bn
# 3      c
# 4    NaN
# 5    con
# 6      b
# 7      c
# dtype: object

# %%
string.str.upper()
# Out:
# 0      A
# 1     DE
# 2     BN
# 3      C
# 4    NaN
# 5    CON
# 6      B
# 7      C
# dtype: object

# %%
string[4]=3
string
# Out:
# 0      A
# 1     DE
# 2     BN
# 3      C
# 4      3
# 5    con
# 6      b
# 7      c
# dtype: object

# %%
df3['e']=np.nan
ff=df3.iloc[9]
ff
print(df3)
print(ff)
# Out:
#    student  grads  studyhour results   e
# a    abdul     70       10.0    pass NaN
# b   haroon     89        2.5    pass NaN
# c      ali     90       20.0    pass NaN
# d    arlan     33       15.0    fail NaN
# e  alishah     78       14.0    pass NaN
# f     saad     90       10.0    pass NaN
# g  rubeena     89        8.0    pass NaN
# h    sadia     88        9.0    pass NaN
# i     rana     87        2.0    pass NaN
# j    rabia    100       11.0    pass NaN
# student      rabia
# grads          100
# studyhour       11
# results       pass
# e              NaN
# Name: j, dtype: object

# %%
df3.fillna(4)
meane=df3.mean()
meane
# Out:
# grads        81.40
# studyhour    10.15
# e              NaN
# dtype: float64

# %%
df3.to_csv('studentfile1.csv')

# %%
df_student=pd.read_csv('studentfile1.csv')
df_student
# Out:
#   Unnamed: 0  student  grads  studyhour results   e
# 0          a    abdul     70       10.0    pass NaN
# 1          b   haroon     89        2.5    pass NaN
# 2          c      ali     90       20.0    pass NaN
# 3          d    arlan     33       15.0    fail NaN
# 4          e  alishah     78       14.0    pass NaN
# 5          f     saad     90       10.0    pass NaN
# 6          g  rubeena     89        8.0    pass NaN
# 7          h    sadia     88        9.0    pass NaN
# 8          i     rana     87        2.0    pass NaN
# 9          j    rabia    100       11.0    pass NaN

# %%
#df3.to_excel('animal.xlsx',sheet_name='Sheet1')

# %%
#df_student2=pd.read_excel('animal.xlsx','Sheet1',index_col=None,na_values=['NA'])

# %% [markdown]
# #visulization in padas

# %%
import numpy as np
# %matplotlib inline
ts=pd.Series(np.random.randn(50),index=pd.date_range('today', periods=50))
ts=ts.cumsum()
ts.plot()

# %%
df=pd.DataFrame(np.random.randn(50,5), index=ts.index,
               columns=['A','B','C','D','E'])
df=df.cumsum()
df.plot()

# %%
import pandas as pd
df=pd.DataFrame({'Q':[1,3,3,3,3,5,6,7,7,8,9,0,10]})
df22=df.loc[ df ['Q'].shift != df['Q'] ]
df22
# Out:
#      Q
# 0    1
# 1    3
# 2    3
# 3    3
# 4    3
# 5    5
# 6    6
# 7    7
# 8    7
# 9    8
# 10   9
# 11   0
# 12  10

# %% [markdown]
# # Load CSV files and play with pandas

# %%
import pandas as pd
df=pd.read_csv('titanic.csv')

# %%
df.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.values.shape
# Out:
# (891, 12)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# 5          False     False   False  False  False   True  False  False   False
# 6          False     False   False  False  False  False  False  False   False
# 7          False     False   False  False  False  False  False  False   False
# 8          False     False   False  False  False  False  False  False   False
# 9          False     False   False  False  False  False  False  False   False
# 10         False     False   False  False  False  False  False  False   False
# ...

# %%
df.fillna(0)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
dfnew=df.copy()
df.head(5)
df=df.fillna(0)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500     0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250     0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500     0        S

# %%
df11=df.to_numpy()

# %%
df11
# Out:
# array([[1, 0, 3, ..., 7.25, 0, 'S'],
#        [2, 1, 1, ..., 71.2833, 'C85', 'C'],
#        [3, 1, 3, ..., 7.925, 0, 'S'],
#        ...,
#        [889, 0, 3, ..., 23.45, 0, 'S'],
#        [890, 1, 1, ..., 30.0, 'C148', 'C'],
#        [891, 0, 3, ..., 7.75, 0, 'Q']], dtype=object)

# %%
stacked = df.stack()

# %%
stacked
# Out:
# 0    PassengerId                                                    1
#      Survived                                                       0
#      Pclass                                                         3
#      Name                                     Braund, Mr. Owen Harris
#      Sex                                                         male
#      Age                                                           22
#      SibSp                                                          1
#      Parch                                                          0
#      Ticket                                                 A/5 21171
#      Fare                                                        7.25
#      Cabin                                                          0
#      Embarked                                                       S
# 1    PassengerId                                                    2
# ...

# %%
df[:2]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500     0        S
# 1      0   PC 17599  71.2833   C85        C

# %%
df.array
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-45f4d85a5b2d> in <module>
# ----> 1 df.array
#
# ~\Anaconda3\envs\testpythorch\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'array'

# %%
df.iloc[1:10]
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   0.0      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# ...

# %%
df[['Name','Sex']].head(5)
# Out:
#                                                 Name     Sex
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male

# %%
df[['Name','Sex']].tail(5)
# Out:
#                                          Name     Sex
# 886                     Montvila, Rev. Juozas    male
# 887              Graham, Miss. Margaret Edith  female
# 888  Johnston, Miss. Catherine Helen "Carrie"  female
# 889                     Behr, Mr. Karl Howell    male
# 890                       Dooley, Mr. Patrick    male

# %%
from sklearn.model_selection import train_test_split

X_all = df.drop(['Survived', 'PassengerId'], axis=1)
y_all = df['Survived']

# %%
df.info()
print('_'*40)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            891 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          891 non-null object
# Embarked       891 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB
# ________________________________________

# %%
X_all.shape
# Out:
# (891, 10)

# %%
y_all.shape
# Out:
# (891,)

# %%
num_test = 0.20
X_train, X_test, y_train, y_test = train_test_split(X_all, y_all, test_size=num_test, random_state=23)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (712, 10)
# (179, 10)
# (712,)
# (179,)

# %%
from sklearn.ensemble import RandomForestClassifier
clf=RandomForestClassifier()
random=clf.fit(X_train,y_train)
# Out:
# C:\Users\moona\Anaconda3\envs\testpythorch\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
data=pd.read_csv('ionosphere.csv')

# %%
data.head(5)
# Out:
#    1  0  0.99539  -0.05889  0.85243  0.02306  0.83398  -0.37708      1.1  \
# 0  1  0  1.00000  -0.18829  0.93035 -0.36156 -0.10868  -0.93597  1.00000
# 1  1  0  1.00000  -0.03365  1.00000  0.00485  1.00000  -0.12062  0.88965
# 2  1  0  1.00000  -0.45161  1.00000  1.00000  0.71216  -1.00000  0.00000
# 3  1  0  1.00000  -0.02401  0.94140  0.06531  0.92106  -0.23255  0.77152
# 4  1  0  0.02337  -0.00592 -0.09924 -0.11949 -0.00763  -0.11824  0.14706
#
#    0.03760  ...  -0.51171  0.41078  -0.46168  0.21266  -0.34090  0.42267  \
# 0 -0.04549  ...  -0.26569 -0.20468  -0.18401 -0.19040  -0.11593 -0.16626
# 1  0.01198  ...  -0.40220  0.58984  -0.22145  0.43100  -0.17365  0.60436
# 2  0.00000  ...   0.90695  0.51613   1.00000  1.00000  -0.20099  0.25682
# 3 -0.16399  ...  -0.65158  0.13290  -0.53206  0.02431  -0.62197 -0.05707
# 4  0.06637  ...  -0.01535 -0.03240   0.09223 -0.07859   0.00732  0.00000
#
#    -0.54487  0.18641  -0.45300  g
# 0  -0.06288 -0.13738  -0.02447  b
# ...

# %%
X_all = data.drop(['g',], axis=1)
y_all = data['g']

# %%
X_all.shape
# Out:
# (350, 34)

# %%
y_all.shape
# Out:
# (350,)

# %%
y_all.head(5)
# Out:
# 0    b
# 1    g
# 2    b
# 3    g
# 4    b
# Name: g, dtype: object

# %%
num_test = 0.20
X_train, X_test, y_train, y_test = train_test_split(X_all, y_all, test_size=num_test, random_state=23)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (280, 34)
# (70, 34)
# (280,)
# (70,)

# %%
from sklearn.ensemble import RandomForestClassifier
clf=RandomForestClassifier()
random=clf.fit(X_train,y_train)
# Out:
# C:\Users\moona\Anaconda3\envs\testpythorch\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
random.predict(X_test)
# Out:
# array(['b', 'b', 'g', 'g', 'g', 'g', 'b', 'g', 'b', 'g', 'g', 'b', 'g',
#        'b', 'b', 'g', 'g', 'g', 'b', 'g', 'g', 'b', 'g', 'b', 'g', 'b',
#        'b', 'b', 'g', 'g', 'g', 'g', 'g', 'g', 'g', 'b', 'g', 'g', 'g',
#        'b', 'g', 'g', 'g', 'b', 'b', 'g', 'b', 'b', 'g', 'g', 'g', 'g',
#        'b', 'b', 'b', 'g', 'g', 'g', 'g', 'g', 'b', 'b', 'g', 'g', 'g',
#        'g', 'g', 'g', 'b', 'b'], dtype=object)

# %%
y_test.shape
# Out:
# (70,)

# %%
print(random.score(X_test,y_test))
print(random.score(X_train,y_train))
# Out:
# 0.9285714285714286
# 0.9928571428571429

# %%
import numpy as np
tt=np.unique(y_train)
tt
# Out:
# array(['b', 'g'], dtype=object)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(X_train,y_train)
knn.predict(X_test)
# Out:
# array(['b', 'b', 'g', 'b', 'g', 'g', 'g', 'g', 'g', 'g', 'g', 'b', 'g',
#        'b', 'g', 'g', 'g', 'g', 'b', 'g', 'g', 'g', 'g', 'b', 'g', 'b',
#        'b', 'g', 'g', 'g', 'g', 'g', 'g', 'g', 'g', 'g', 'g', 'g', 'g',
#        'b', 'g', 'g', 'g', 'g', 'g', 'g', 'g', 'b', 'g', 'g', 'g', 'g',
#        'b', 'b', 'g', 'g', 'g', 'g', 'g', 'g', 'g', 'b', 'g', 'g', 'g',
#        'b', 'g', 'g', 'b', 'b'], dtype=object)

# %%
knn.score(X_test,y_test)
# Out:
# 0.8

# %%
from sklearn import svm
svc=svm.SVC(kernel='linear')
svc.fit(X_train,y_train)
svc.predict(X_test)
svc.score(X_test,y_test)
# Out:
# 0.8571428571428571

# %%
svc
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='linear', max_iter=-1, probability=False, random_state=None,
#   shrinking=True, tol=0.001, verbose=False)

# %%
svc = svm.SVC(kernel='rbf')
svc.fit(X_train,y_train)
svc.predict(X_test)
svc.score(X_test,y_test)
# Out:
# C:\Users\moona\Anaconda3\envs\testpythorch\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# 0.9428571428571428

# %%
clf = svm.SVC(gamma=0.001, C=100.)
clf.fit(X_train,y_train)
clf.predict(X_test)
clf.score(X_test,y_test)
# Out:
# 0.8857142857142857

# %%
clf = svm.SVC(gamma='scale')
clf.fit(X_train,y_train)
clf.predict(X_test)
clf.score(X_test,y_test)
# Out:
# 0.9571428571428572
